# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize']=6,3

import warnings 
warnings.filterwarnings ('ignore')

# %%
df=pd.read_excel(r"C:\Users\artem\OneDrive - Indian Oil Corporation Limited\Documents\Gen AI and Agenetic AI\1. 14.12.2025 Basic Python\data.xlsx")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
vis1= sns.distplot(df["InternetUsers"])

# %%
vis2= sns.distplot(df["InternetUsers"], bins=15)

# %%
vis3= sns.boxplot(data=df, x="IncomeGroup", y='BirthRate')
# Box Plot

# %% [markdown]
# ### This is a bivariate anaysis as we are plotting using 2 variables

# %% [markdown]
# Outlier: In statistics, outlier is the data point which is very far from individual data points

# %% [markdown]
# ## Lmpolot

# %%
vis5= sns.lmplot(data=df, x= "InternetUsers", y="BirthRate")

# %%
vis5= sns.lmplot(data=df, x= "InternetUsers", y="BirthRate", fit_reg=False)

# %%
vis5= sns.lmplot(data=df, x= "InternetUsers", y="BirthRate", fit_reg=False, hue="IncomeGroup")

# %%
vis5= sns.lmplot(data=df, x= "InternetUsers", y="BirthRate", fit_reg=True, hue="IncomeGroup")
