# %%
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader('speech.txt', encoding="utf-8")
loader

# %%
text_documents= loader.load()

# %%
from langchain_community .document_loaders import PyPDFLoader
loader=PyPDFLoader('test_doc.pdf')

# %%
docs=loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-02-27T10:21:42+05:30', 'author': '', 'moddate': '2026-02-27T10:21:42+05:30', 'title': 'Regular Summarization_ 530 PM.xlsx', 'source': 'test_doc.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='06-02-2026 cross validation  & clustering \nk-fold cv -- when the models are overfiting there we implement k fold cv \ndataset we divide into 1000 records divided into 5 fold . Each folds contain 200 recording build model 5 times \naverage of all the 5 models then we calculate ( reduce high var - low var ) reduce overfitting technique \nmodel tunning -- gridsearch cv & random search cv \nwe pass each and every model parameters ( manually assigne all the parameter in one go) grid search cv will \nfinetune optimized parameter  | discussed math for k-meas\nclustering -- grouping | no dependent variable | data is discreate we are using \ncustomer segmentation, rating the food, gr
# ...

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
import bs4

# %%
# Web based loader
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_paths=["https://en.wikipedia.org/wiki/Boeing_C-17_Globemaster_III"],
                     bs_kwargs=dict(parse_only=bs4.SoupStrainer(class_=("post-title","post-content","post-header"))))

# %%
data=loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Boeing_C-17_Globemaster_III'}, page_content='')]

# %%
from langchain_community.document_loaders import WikipediaLoader
docs=WikipediaLoader(query="Sukhoi 30", load_max_docs=2).load()
len(docs)
print(docs)
# Out:
# [Document(metadata={'title': 'Sukhoi Su-30MKI', 'summary': "The Sukhoi Su-30MKI (NATO reporting name: Flanker-H) is a two-seater, twinjet multirole air superiority fighter developed by Russian aircraft manufacturer Sukhoi and built under licence by India's Hindustan Aeronautics Limited (HAL) for the Indian Air Force (IAF). A variant of the Sukhoi Su-30, it is a heavy, all-weather, long-range fighter.\nDevelopment of the variant started after India signed a deal with Russia in 2000 to manufacture 140 Su-30 fighter aircraft. The first Russian-made Su-30MKI variant was accepted into the Indian Air Force in 2002, while the first Su-30MKI assembled in India entered service with the IAF in November 2004. The IAF has nearly 260 Su-30MKIs in inventory as of January 2020. The Su-30MKI was expected to form the backbone of the IAF's fighter fleet beyond 2020.\nThe aircraft is tailor-made for Indian specifications and integrates Indian systems and avionics as well as French and Israeli sub-syste
# ...
