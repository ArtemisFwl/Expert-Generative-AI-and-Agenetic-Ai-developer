# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings=(OllamaEmbeddings(model="gemma:2b"))
# Out:
# C:\Users\Aman Deep\AppData\Local\Temp\ipykernel_19792\3421749802.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings=(OllamaEmbeddings(model="gemma:2b"))

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(
    [
        "My name is aman deep",
        "Pichhuka likes to eat rice"
    ]
)

# %%
r1
# Out:
# [[-0.4588506519794464,
#   -0.0417022705078125,
#   -1.6277275085449219,
#   1.8591057062149048,
#   1.0603681802749634,
#   0.3508736789226532,
#   -0.15548411011695862,
#   -0.3482154905796051,
#   1.51973557472229,
#   0.6363421678543091,
#   0.7958444356918335,
#   1.5690581798553467,
#   -0.6545278429985046,
#   0.5752710700035095,
#   -1.026248812675476,
#   -0.6544938683509827,
#   3.421475648880005,
#   -1.9218792915344238,
#   0.919809877872467,
#   1.4728386402130127,
#   0.11248069256544113,
#   0.27381816506385803,
#   -1.2063153982162476,
#   -0.4336031377315521,
#   -0.4189985692501068,
#   -0.41050705313682556,
#   0.863455593585968,
#   -1.4141225814819336,
#   1.0475635528564453,
#   0.2766544818878174,
#   -0.13081517815589905,
#   0.12969329953193665,
#   0.04034003987908363,
#   0.8364621996879578,
#   1.4228309392929077,
#   -1.0549241304397583,
#   1.545483112335205,
#   -0.26780223846435547,
#   -0.6429238319396973,
#   -0.4278048574924469,
# ...

# %%
len(r1[0])
# Out:
# 2048
