# %%
#pip install -U langgraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langgraph in c:\users\aman deep\appdata\roaming\python\python313\site-packages (1.0.10)
# Collecting langgraph
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langgraph) (1.2.17)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langgraph) (4.0.1)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph)
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langgraph) (0.3.9)
# Requirement already satisfied: pydantic>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langgraph) (2.12.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\programdata\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langchain-core>=0.1->langgraph) (0.7.14)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aman deep\appdata\roaming\python\python313\site-packages (from langchain-core>=0.1->langgraph) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.0)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
# Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Installing collected packages: langgraph-prebuilt, langgraph
#
#   Attempting uninstall: langgraph-prebuilt
#
#     Found existing installation: langgraph-prebuilt 1.0.8
#
#     Uninstalling langgraph-prebuilt-1.0.8:
#
#       Successfully uninstalled langgraph-prebuilt-1.0.8
#
#    ---------------------------------------- 0/2 [langgraph-prebuilt]
#   Attempting uninstall: langgraph
#    ---------------------------------------- 0/2 [langgraph-prebuilt]
#     Found existing installation: langgraph 1.0.10
#    ---------------------------------------- 0/2 [langgraph-prebuilt]
#    -------------------- ------------------- 1/2 [langgraph]
#     Uninstalling langgraph-1.0.10:
#    -------------------- ------------------- 1/2 [langgraph]
#       Successfully uninstalled langgraph-1.0.10
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    -------------------- ------------------- 1/2 [langgraph]
#    ---------------------------------------- 2/2 [langgraph]
#
# Successfully installed langgraph-1.1.6 langgraph-prebuilt-1.0.9
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 1.2.10 requires langgraph<1.1.0,>=1.0.8, but you have langgraph 1.1.6 which is incompatible.

# %%
from typing_extensions import TypedDict
from IPython.display import Image, display 
from langgraph.graph import StateGraph, END

# %%
class MyState(TypedDict):
    message: str

# Define the start node
def start_node(state: MyState) -> MyState:
    print("Start node received:", state["message"])
    # Process or pass the message to the end node
    return {"message": state["message"] + " -> processed by start"}

# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# Build the graph
builder = StateGraph(MyState)


# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# %%
# Build the graph
builder = StateGraph(MyState)

# %%
# Add nodes
builder.add_node("start", start_node)
builder.add_node("end", end_node)

# %%
# Define the flow
builder.set_entry_point("start")
builder.add_edge("start", "end")
builder.add_edge("end", END)  # END is a special marker for graph completion

# %%
# Compile the graph
graph = builder.compile()

# Run the graph
result = graph.invoke({"message": "Hello LangGraph"})
print("Final result:", result["message"])
# Out:
# Start node received: Hello LangGraph
# End node received: Hello LangGraph -> processed by start
# Final result: Hello LangGraph -> processed by start
