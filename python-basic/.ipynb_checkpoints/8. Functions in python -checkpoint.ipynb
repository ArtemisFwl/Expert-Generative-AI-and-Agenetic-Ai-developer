# %% [markdown]
# ### Functions in python

# %% [markdown]
# ## Types of Arguments in Python
#
# ### 1️⃣ Formal Arguments
# - Defined **at the time of function definition**
# - These act as placeholders for values
#
# ---
#
# ### 2️⃣ Actual Arguments
# - Passed **while calling the function**
# - These provide real values to the function
#
# #### Types of Actual Arguments:
#
# - **Positional Arguments**
#   Arguments passed in the same order as function parameters
#
# - **Keyword Arguments**
#   Arguments passed using `parameter = value` format
#
# - **Default Arguments**
#   Parameters that have a default value if no argument is provided
#
# - **Variable Length Arguments (`*args`)**
#   Used when the number of arguments is not fixed
#   Collects values into a **tuple**
#
# - **Keyword Variable Length Arguments (`**kwargs`)**
#   Used for variable-length **keyword** arguments
#   Collects values into a **dictionary**

# %%
def greet():
    print("good morning Sparrow")

greet()
# Out:
# good morning Sparrow

# %%
def add(x,y):
    c=x+y
    print(c)

add(5,6)
# Out:
# 11

# %% [markdown]
# a and y are formal arguments
#
#
# 5,5 are actual arguments

# %%
def add(x,y):
    c=x+y
    return c

add(86,6)
# Out:
# 92

# %%
greet()
# Out:
# good morning Sparrow

# %%
add(15,32)
# Out:
# 47

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d

# %%
add_sub(8,5)
# Out:
# (13, 3)

# %%
z=add_sub(8,5)

# %%
type(z)
# Out:
# tuple

# %%
r1, r2=add_sub(8,5)

# %%
type(r1)
# Out:
# int

# %%
type (r2)
# Out:
# int

# %%
def add(a,b):
    c=a+b
    return c

add(4,5)
# Out:
# 9

# %% [markdown]
# ### Positional Arguments

# %%
def person(name , age):
    print(name)
    print(age)

# %%
person ("aman", 21)
# Out:
# aman
# 21

# %%
person (21, "Aman")
# Out:
# 21
# Aman

# %%
person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-43efcf4528f4> in <module>
# ----> 1 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
person(22)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-9624d1d919cd> in <module>
# ----> 1 person(22)
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name, age):
    print(name)
    print(age - 1)

# %%
person("aman", 30)
# Out:
# aman
# 29

# %%
person(30,"Aman ")
# Out:
# 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-28f92c9ec658> in <module>
# ----> 1 person(30,"Aman ")
#
# <ipython-input-26-8634f47d86e7> in person(name, age)
#       1 def person(name, age):
#       2     print(name)
# ----> 3     print(age - 1)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# ### TO ignore these error messages we use keyword arguments

# %%
person(age=22, name="Aman")
# Out:
# Aman
# 21

# %%
person(age=22, name1="Aman")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0d044caa90e5> in <module>
# ----> 1 person(age=22, name1="Aman")
#
# TypeError: person() got an unexpected keyword argument 'name1'

# %%
def person(name, age, age2):
    print(name)
    print(age - 1)

# %%
person(age=22, name1="Aman", 23)
# Out:
#   File "<ipython-input-34-031f50ed105b>", line 1
#     person(age=22, name1="Aman", 23)
#                                  ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ### Default Arguments

# %%
def person (name, age=18):
    print(name)
    print(age)
    
person('nit')
# Out:
# nit
# 18

# %%
person('nit', 25)
# Out:
# nit
# 25

# %% [markdown]
# If no value is passed as argument for age, by default it will take it as 18

# %% [markdown]
# ### Variable length argument

# %%
def add(a,b):
    c=a+b
    return c

# %%
sum(1,2,3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-5f8d8012427f> in <module>
# ----> 1 sum(1,2,3,4,5,6)
#
# TypeError: sum() takes at most 2 arguments (6 given)

# %%
def sum(a, *b):
    c=a+b
    return c

sum(1,2,3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-90e2a08d974a> in <module>
#       3     return c
#       4
# ----> 5 sum(1,2,3,4,5,6)
#
# <ipython-input-47-90e2a08d974a> in sum(a, *b)
#       1 def sum(a, *b):
# ----> 2     c=a+b
#       3     return c
#       4
#       5 sum(1,2,3,4,5,6)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
## Put it in loop

def sum (a,*b):
    c=a
    for i in b:
        c=c+i
    print(c)

# %%
sum(1,5,3,55,7,8,5,4)
# Out:
# 88

# %% [markdown]
# ### Keyword variable length argument (kwarg)-- keyword + variable length

# %%
def person():
    person('ALEX', 36, 'JHON', 998588)

# %%
def person (name, *data):
    print(name)
    print(data)
    
person ('ALEX', 36, 'JHON', 959826548)
# Out:
# ALEX
# (36, 'JHON', 959826548)

# %%
def person (name, *data):
    print(name)
    print(data)
    
person ('ALEX', age=36, home_name='JHON', mob=959826548)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-8d06f0a07f95> in <module>
#       3     print(data)
#       4
# ----> 5 person ('ALEX', age=36, home_name='JHON', mob=959826548)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person (name, **data):
    print(name)
    print(data)
    
person ('ALEX', age=36, home_name='JHON', mob=959826548)
# Out:
# ALEX
# {'age': 36, 'home_name': 'JHON', 'mob': 959826548}

# %% [markdown]
# In keyword variable length argument we use 2 stas **

# %% [markdown]
# We learnt, what is function, how to call function, what is formal argument and what is actual argument

# %% [markdown]
# ### Local and global variables

# %%
a=10 # Global variable 

def something ():
    b=15 # Local variable 
    
    print ('in function',b)
    print('out function',a)

# %%
a=10 # Global variable 

def something ():
    b=15 # Local variable 
    
    print ('in function',b)
print('out function',a)
# Out:
# out function 10

# %%
print ('in function',b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-f89e555ff322> in <module>
# ----> 1 print ('in function',b)
#
# NameError: name 'b' is not defined

# %%
something()
# Out:
# in function 15

# %%
# Global variable
x = 10  

def update_x():
    global x      # Declare that we are using the global variable x
    x += 5        # Modify the global variable

update_x()
print(x)          # Output: 15
# Out:
# 15

# %%
# Using globals() to modify a global variable

x = 10  # Global variable

def update_x():
    globals()['x'] += 5   # Access and modify the global variable using globals()

update_x()
print(x)                  # Output: 15
# Out:
# 15
