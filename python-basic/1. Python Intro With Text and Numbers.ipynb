# %% [markdown]
# # Working with python numbers and String
#
# ## Aman Deep

# %%
6
# Out:
# 6

# %%
-5
# Out:
# -5

# %%
5+6
# Out:
# 11

# %%
5+6-7*3-7
# Out:
# -17

# %%
5+6-7*(3-7)
# Out:
# 39

# %%
_ # Underscore Stores the Previous Value
# Out:
# 39

# %%
_+3
# Out:
# 42

# %%
_+3
# Out:
# 45

# %%
_=4  # Here 4 is assigned to _

# %%
_
# Out:
# 4

# %%
_-2
# Out:
# 2

# %%
a=3
b=4

# %%
int.__add__(a,b)
# Out:
# 7

# %%
int.__sub__(a,b)
# Out:
# -1

# %%
int.__mul__(a,b)
# Out:
# 12

# %%
a='Aman'
b='Deep'

# %%
int.__add__(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-bdc43f10e6f5> in <module>
# ----> 1 int.__add__(a,b)
#
# TypeError: descriptor '__add__' requires a 'int' object but received a 'str'

# %%
str.__add__(a,b)
# Out:
# 'AmanDeep'

# %%
# Work With text

# %%
amandeep
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-992f9eefeb27> in <module>
# ----> 1 amandeep
#
# NameError: name 'amandeep' is not defined

# %%
'Aman'
# Out:
# 'Aman'

# %%
"Aman"
# Out:
# 'Aman'

# %%
'''Aman'''
# Out:
# 'Aman'

# %%
'Aman
Deep'
# Out:
#   File "<ipython-input-32-79fccf8ba31d>", line 1
#     'Aman
#          ^
# SyntaxError: EOL while scanning string literal

# %%
"Aman
Deep"
# Out:
#   File "<ipython-input-33-4a639ed5dbb2>", line 1
#     "Aman
#          ^
# SyntaxError: EOL while scanning string literal

# %%
'''Aman 
Deep'''
# Out:
# 'Aman \nDeep'

# %% [markdown]
# ## Basic String Completed
