# %% [markdown]
# Topics covered:
#
# 1.Python datatypes- Int, float, bool, complex, string
#
# 2.Typecasting from one datatype to other
#
# 3.Print Function

# %% [markdown]
# ### Python Datatypes

# %% [markdown]
# ### Int and float

# %%
a=5

# %%
type(a)
# Out:
# int

# %%
'''
a is variable 
5 is value i.e datatype
'''
# Out:
# '\na is variable \n5 is value i.e datatype\n'

# %% [markdown]
# ####  int - number without decimal
# ####  float - Integer with decimal
# #### in float, e is allowed e=10

# %%
f1= 1e0

# %%
f1
# Out:
# 1.0

# %%
f2 = 2e2

# %%
f2
# Out:
# 200.0

# %%
type (f2)
# Out:
# float

# %% [markdown]
# #### boolean

# %%
c= true # true has to start with capital no. else it has to be string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-61b85b943e4e> in <module>
# ----> 1 c= true # true has to start with capital no. else it has to be string
#
# NameError: name 'true' is not defined

# %%
c='true'

# %%
b= True
b1= False

# %%
b+b1
# Out:
# 1

# %%
print(b+b1)
print(b-b1)
print(b*b1)
# Out:
# 1
# 1
# 0

# %%
b/b
# Out:
# 1.0

# %%
b//b
# Out:
# 1

# %%
False/ True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %% [markdown]
# In python :
#
# //: Int division
#
# / : float division

# %% [markdown]
# ### Complex
#
# #### Comples is noly present in python. Not present in any other programming language

# %%
#Syntax: a+bj

# %%
c=10+20j

# %%
type(c)
# Out:
# complex

# %%
c.imag
# Out:
# 20.0

# %%
c.real
# Out:
# 10.0

# %%
c.conjugate()oo41
# Out:
# (10-20j)

# %%
c1= 2+4.5j

# %%
c2= 2.5+6j

# %%
c1+c2
# Out:
# (4.5+10.5j)

# %% [markdown]
# ## String

# %%
## String Indexing
        # forward indexing: always begins with 0 
        # backward indexing always begins with -1

# %%
s="prakash"

# %%
s
# Out:
# 'prakash'

# %%
s[0]
# Out:
# 'p'

# %%
s[-1]
# Out:
# 'h'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-34c622ab6870> in <module>
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
s[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-e045f2696f3a> in <module>
# ----> 1 s[-10]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'prakash'

# %%
s[2:] #print the element or values from second index
# Out:
# 'akash'

# %%
s[:5] # Print element or value from start index to n-1
# Out:
# 'praka'

# %%
s[0:6:2]
# Out:
# 'paa'

# %%
s
# Out:
# 'prakash'

# %%
s[-3]
# Out:
# 'a'

# %%
s[-2:]
# Out:
# 'sh'

# %%
s[-5:]
# Out:
# 'akash'

# %%
s[-5]
# Out:
# 'a'

# %%
s[-7:-4] # PRAKASH -7 -6 -5 -4 -3 -2 -1
# Out:
# 'pra'

# %% [markdown]
# ## PRAKASH
# ## -7 -6 -5 -4 -3 -2 -1

# %%
s[2:-2]
# Out:
# 'aka'

# %% [markdown]
# ### Language == Text
#
# #### When text is large, ecosystem is created to handle large text by open AI. THat ecosystem is LLM. It is called large language model.

# %% [markdown]
# #### Function and arguments
#
#
# #### car (swift)
# #### car (swift, audi, bmw)
#
#
# ### ========================

# %% [markdown]
# ## Python typecasting

# %%
type(100.3)
# Out:
# float

# %%
int(100.3)
# Out:
# 100

# %%
int(True)
# Out:
# 1

# %%
int(1+2j) # Complex cannot be converted to integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-001fe75ed540> in <module>
# ----> 1 int(1+2j) # Complex cannot be converted to integer
#
# TypeError: can't convert complex to int

# %%
int('10') # Numerical int can be converted
# Out:
# 10

# %%
int('ten') # String cannot be converted to it
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-12a85981658c> in <module>
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# ### We can typecast from other datatypes to float except complex and string

# %%
float(2)
# Out:
# 2.0

# %%
float('10')
# Out:
# 10.0

# %%
float(1+2j) # Complex does not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-7aeb538bb9dc> in <module>
# ----> 1 float(1+2j) # Complex does not work
#
# TypeError: can't convert complex to float

# %%
complex(8)
# Out:
# (8+0j)

# %%
complex(8,10)
# Out:
# (8+10j)

# %%
complex(8,10,12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d407ea9df0ce> in <module>
# ----> 1 complex(8,10,12)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3, 2.5)
# Out:
# (2.3+2.5j)

# %%
complex('20',10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-08e9ee8c3862> in <module>
# ----> 1 complex('20',10)
#
# TypeError: complex() can't take second arg if first is a string

# %%
### Complex cannot take second arg if first is string

# %%
complex('20','10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1a68ab0e8e42> in <module>
# ----> 1 complex('20','10')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('20')
# Out:
# (20+0j)

# %%
complex(20,'10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-43c94cb10468> in <module>
# ----> 1 complex(20,'10')
#
# TypeError: complex() second arg can't be a string

# %%
# Second argument in complex cannot be string

# %%
### We can typecast from other datatype to complex except second parameter cannot be string

# %%
## Print

# %%
# Out:
# 2

# %%
print(str(2))
print(str(2.3))
print(str(1+2j))
# Out:
# 2
# 2.3
# (1+2j)

# %%
x=str(True)

# %%
type(x)
# Out:
# str

# %%
type('True')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ### We can typecast from other datatype to string. No problem

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# ### Non zero argument gives zero and zero arg gives false

# %%
bool(1+2j)
# Out:
# True

# %%
bool() # Empty Space
# Out:
# False

# %%
bool(2j)
# Out:
# True

# %%
bool("AMan ")
# Out:
# True

# %% [markdown]
# ### We can typecast all other datatype to boolean. No problem

# %% [markdown]
# # Print Function

# %%
num1, num2= 20,30

add= num1+num2

# %% [markdown]
# ## Print result with string

# %%
print ("Addition of", num1, 'and ', num2, 'is', add )
# Out:
# Addition of 20 and  30 is 50

# %%
Name= "Aman"
age=30
City="Hyd"

# %%
print('Hello, My name is ',Name, ' I am', age, 'years old. I belong to ',City)
# Out:
# Hello, My name is  Aman  I am 30 years old. I belong to  Hyd

# %%
num1, num2= 20,30
add= num1+num2

# %% [markdown]
# ### .format method

# %%
print("THe addition of {} and {} is {}".format(num1, num2, add))
# Out:
# THe addition of 20 and 30 is 50

# %%
Name= "Aman"
age=30
City="Hyd"

# %%
print("My name is {} and I am {} years old and I belong to {}".format(Name, age, City))
# Out:
# My name is Aman and I am 30 years old and I belong to Hyd

# %% [markdown]
# ## f string method

# %%
# Short form format. Variables are defined in curly braces

# %%
num1, num2= 20,30
add= num1+num2

# %%
print(f"THe sum of {num1} and {num2} is {add}")
# Out:
# THe sum of 20 and 30 is 50

# %% [markdown]
# ## ENd Statement

# %%
print('hello')
print('Good Morning ')
# Out:
# hello
# Good Morning

# %%
print('hello', end=" ")
print('Good Morning ')
# Out:
# hello Good Morning

# %%
print('*', end='')
print('*')
# Out:
# **

# %% [markdown]
# ## Seperator

# %%
print("Hellp", "Hai", "How", "Are", "You", sep="---->")
# Out:
# Hellp---->Hai---->How---->Are---->You
