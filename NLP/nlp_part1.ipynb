# %%
import os
import nltk
#nltk.download()

# %%
import nltk.corpus

# %%
AI ='''
In a world that never seems to slow down, the ability to sit quietly with your own thoughts has become a rare strength. Most people chase constant stimulation—notifications, reels, noise, and endless opinions—yet real clarity often arrives in silence. When you pause and reflect, you begin to understand your patterns, your fears, and your true ambitions. Growth does not usually come from dramatic breakthroughs but from small, consistent actions taken every day. A person who chooses discipline over distraction, even in tiny moments, slowly reshapes their future. Over time, these invisible choices compound, building confidence, resilience, and a deeper sense of purpose.

'''

# %%
AI
# Out:
# '\nIn a world that never seems to slow down, the ability to sit quietly with your own thoughts has become a rare strength. Most people chase constant stimulation—notifications, reels, noise, and endless opinions—yet real clarity often arrives in silence. When you pause and reflect, you begin to understand your patterns, your fears, and your true ambitions. Growth does not usually come from dramatic breakthroughs but from small, consistent actions taken every day. A person who chooses discipline over distraction, even in tiny moments, slowly reshapes their future. Over time, these invisible choices compound, building confidence, resilience, and a deeper sense of purpose.\n\n'

# %%
type(AI)
# Out:
# str

# %%
print(os.listdir(nltk.data.find('corpora')))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'bcp47.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'english_wordnet', 'english_wordnet.zip', 'europarl_raw', 'europarl_raw.zip', 'extended_omw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
AI_tokens= word_tokenize(AI)

# %%
AI_tokens
# Out:
# ['In',
#  'a',
#  'world',
#  'that',
#  'never',
#  'seems',
#  'to',
#  'slow',
#  'down',
#  ',',
#  'the',
#  'ability',
#  'to',
#  'sit',
#  'quietly',
#  'with',
#  'your',
#  'own',
#  'thoughts',
#  'has',
#  'become',
#  'a',
#  'rare',
#  'strength',
#  '.',
#  'Most',
#  'people',
#  'chase',
#  'constant',
#  'stimulation—notifications',
#  ',',
#  'reels',
#  ',',
#  'noise',
#  ',',
#  'and',
#  'endless',
#  'opinions—yet',
#  'real',
#  'clarity',
#  'often',
#  'arrives',
#  'in',
#  'silence',
#  '.',
#  'When',
#  'you',
#  'pause',
#  'and',
#  'reflect',
#  ',',
#  'you',
#  'begin',
#  'to',
#  'understand',
#  'your',
#  'patterns',
#  ',',
#  'your',
#  'fears',
#  ',',
#  'and',
#  'your',
#  'true',
#  'ambitions',
#  '.',
#  'Growth',
#  'does',
#  'not',
#  'usually',
#  'come',
#  'from',
#  'dramatic',
#  'breakthroughs',
#  'but',
#  'from',
#  'small',
#  ',',
#  'consistent',
#  'actions',
#  'taken',
#  'every',
#  'day',
#  '.',
#  'A',
# ...

# %%
len(AI_tokens)
# Out:
# 122

# %%
from nltk.tokenize import sent_tokenize

# %%
AI_sent=sent_tokenize(AI)
AI_sent
# Out:
# ['\nIn a world that never seems to slow down, the ability to sit quietly with your own thoughts has become a rare strength.',
#  'Most people chase constant stimulation—notifications, reels, noise, and endless opinions—yet real clarity often arrives in silence.',
#  'When you pause and reflect, you begin to understand your patterns, your fears, and your true ambitions.',
#  'Growth does not usually come from dramatic breakthroughs but from small, consistent actions taken every day.',
#  'A person who chooses discipline over distraction, even in tiny moments, slowly reshapes their future.',
#  'Over time, these invisible choices compound, building confidence, resilience, and a deeper sense of purpose.']

# %%
len(AI_sent)
# Out:
# 6

# %%
from nltk.tokenize import blankline_tokenize
AI_blank=blankline_tokenize(AI)
AI_blank
# Out:
# ['\nIn a world that never seems to slow down, the ability to sit quietly with your own thoughts has become a rare strength. Most people chase constant stimulation—notifications, reels, noise, and endless opinions—yet real clarity often arrives in silence. When you pause and reflect, you begin to understand your patterns, your fears, and your true ambitions. Growth does not usually come from dramatic breakthroughs but from small, consistent actions taken every day. A person who chooses discipline over distraction, even in tiny moments, slowly reshapes their future. Over time, these invisible choices compound, building confidence, resilience, and a deeper sense of purpose.']

# %%
len(AI_blank)
# Out:
# 1

# %%
from nltk import WhitespaceTokenizer
ws=WhitespaceTokenizer().tokenize(AI)

# %%
ws
# Out:
# ['In',
#  'a',
#  'world',
#  'that',
#  'never',
#  'seems',
#  'to',
#  'slow',
#  'down,',
#  'the',
#  'ability',
#  'to',
#  'sit',
#  'quietly',
#  'with',
#  'your',
#  'own',
#  'thoughts',
#  'has',
#  'become',
#  'a',
#  'rare',
#  'strength.',
#  'Most',
#  'people',
#  'chase',
#  'constant',
#  'stimulation—notifications,',
#  'reels,',
#  'noise,',
#  'and',
#  'endless',
#  'opinions—yet',
#  'real',
#  'clarity',
#  'often',
#  'arrives',
#  'in',
#  'silence.',
#  'When',
#  'you',
#  'pause',
#  'and',
#  'reflect,',
#  'you',
#  'begin',
#  'to',
#  'understand',
#  'your',
#  'patterns,',
#  'your',
#  'fears,',
#  'and',
#  'your',
#  'true',
#  'ambitions.',
#  'Growth',
#  'does',
#  'not',
#  'usually',
#  'come',
#  'from',
#  'dramatic',
#  'breakthroughs',
#  'but',
#  'from',
#  'small,',
#  'consistent',
#  'actions',
#  'taken',
#  'every',
#  'day.',
#  'A',
#  'person',
#  'who',
#  'chooses',
#  'discipline',
#  'over',
#  'distraction,',
#  'even',
# ...

# %%
s="Cost of a good apple is 12$. Please buy it brother."
# What if there is a number betwen the text

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(s)
# Out:
# ['Cost',
#  'of',
#  'a',
#  'good',
#  'apple',
#  'is',
#  '12',
#  '$.',
#  'Please',
#  'buy',
#  'it',
#  'brother',
#  '.']

# %%
import nltk

# %%
from nltk.util import bigrams, trigrams, ngrams

# %%
string=" I am Aman Deep. I am working in IOCL"

# %%
quotes_tokens=nltk.word_tokenize(string)

# %%
quotes_tokens
# Out:
# ['I', 'am', 'Aman', 'Deep', '.', 'I', 'am', 'working', 'in', 'IOCL']

# %%
len(quotes_tokens)
# Out:
# 10

# %%
quotes_bigram= list(nltk.bigrams(quotes_tokens))
quotes_bigram
# Out:
# [('I', 'am'),
#  ('am', 'Aman'),
#  ('Aman', 'Deep'),
#  ('Deep', '.'),
#  ('.', 'I'),
#  ('I', 'am'),
#  ('am', 'working'),
#  ('working', 'in'),
#  ('in', 'IOCL')]

# %%
quotes_trigram= list(nltk.trigrams(quotes_tokens))
quotes_trigram
# Out:
# [('I', 'am', 'Aman'),
#  ('am', 'Aman', 'Deep'),
#  ('Aman', 'Deep', '.'),
#  ('Deep', '.', 'I'),
#  ('.', 'I', 'am'),
#  ('I', 'am', 'working'),
#  ('am', 'working', 'in'),
#  ('working', 'in', 'IOCL')]

# %%
quotes_ngram=list(nltk.ngrams(quotes_tokens, 5))
quotes_ngram
# Out:
# [('I', 'am', 'Aman', 'Deep', '.'),
#  ('am', 'Aman', 'Deep', '.', 'I'),
#  ('Aman', 'Deep', '.', 'I', 'am'),
#  ('Deep', '.', 'I', 'am', 'working'),
#  ('.', 'I', 'am', 'working', 'in'),
#  ('I', 'am', 'working', 'in', 'IOCL')]

# %%
#Stemming

# %%
words_to_stem = [
    "playing", "played", "plays", "player",
    "happiness", "happy",
    "running", "runs", "runner",
 
]

# %%
from nltk.stem import PorterStemmer
pst=PorterStemmer()

# %%
for words in words_to_stem:
    print(words+ ':'+ pst.stem(words))
# Out:
# playing:play
# played:play
# plays:play
# player:player
# happiness:happi
# happy:happi
# running:run
# runs:run
# runner:runner

# %%
from nltk.stem import LancasterStemmer
lcstmr= LancasterStemmer()

# %%
for words in words_to_stem:
    print(words + ":"+ lcstmr.stem(words))
# Out:
# playing:play
# played:play
# plays:play
# player:play
# happiness:happy
# happy:happy
# running:run
# runs:run
# runner:run

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_lem=WordNetLemmatizer()

# %%
for words in words_to_stem:
    print("Lemmatization of "+words + " is " + word_lem.lemmatize(words))
# Out:
# Lemmatization of playing is playing
# Lemmatization of played is played
# Lemmatization of plays is play
# Lemmatization of player is player
# Lemmatization of happiness is happiness
# Lemmatization of happy is happy
# Lemmatization of running is running
# Lemmatization of runs is run
# Lemmatization of runner is runner

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
len(stopwords.words('french'))
# Out:
# 157

# %%
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')   # first time only
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Aman
# [nltk_data]     Deep\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sent= 'Sam is natural when it comes to drawing'
sent_tokens=word_tokenize(sent)
sent_tokens
# Out:
# ['Sam', 'is', 'natural', 'when', 'it', 'comes', 'to', 'drawing']

# %%
for token in sent_tokens:
    print(nltk.pos_tag([token]))
# Out:
# [('Sam', 'NNP')]
# [('is', 'VBZ')]
# [('natural', 'JJ')]
# [('when', 'WRB')]
# [('it', 'PRP')]
# [('comes', 'VBZ')]
# [('to', 'TO')]
# [('drawing', 'VBG')]
