# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
words=['go', 'going', 'eating', 'eaten', 'gone', 'eat', 'history', 'finally']

# %%
for word in words:
    print(word+"---->"+stemming.stem(word))
# Out:
# go---->go
# going---->go
# eating---->eat
# eaten---->eaten
# gone---->gone
# eat---->eat
# history---->histori
# finally---->final
