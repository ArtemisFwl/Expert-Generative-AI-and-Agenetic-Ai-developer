# %%
#pip install -U langchain-google-genai

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyD4HDfcxzZ6ODUj-ZbO1QwhHR0oc_QmKeA"

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gemini-2.5-flash", model_provider="google_genai")

# %%
response = model.invoke("Explain AI in 2 lines")

print(response.content)
# Out:
# AI enables machines to learn, reason, and understand like humans.
# This allows them to perform complex tasks, solve problems, and make decisions.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages=[
    SystemMessage("Translate following english in Hindi"),
    HumanMessage("You should never trust humans"),
]

model.invoke(messages)
# Out:
# AIMessage(content="यहां कुछ तरीके दिए गए हैं, जो संदर्भ के आधार पर थोड़े अलग हो सकते हैं:\n\n1.  **इंसानों पर कभी भरोसा नहीं करना चाहिए।** (Insaano par kabhi bharosa nahin karna chahiye.) - *यह सबसे सीधा और सामान्य अनुवाद है।*\n2.  **आपको इंसानों पर कभी भरोसा नहीं करना चाहिए।** (Aapko insaano par kabhi bharosa nahin karna chahiye.) - *यदि आप किसी विशिष्ट व्यक्ति को सलाह दे रहे हैं, तो 'आपको' जोड़ सकते हैं।*\n3.  **मनुष्यों पर कभी विश्वास न करें।** (Manushyon par kabhi vishwas na karein.) - *थोड़ा अधिक औपचारिक या साहित्यिक।*", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cce44-a76b-7e72-b6f9-b303536205a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1314, 'total_tokens': 1325, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1169}})

# %%
model.invoke("Hello")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cce47-386e-7da3-a8a4-8291644c2a6f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 219, 'total_tokens': 221, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 210}})

# %% [markdown]
# ### Prompt Templates

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "odia", "text": "how are you"})
prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}), HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})]

# %%
response=model.invoke(prompt)

# %%
print(response.content)
# Out:
# **କେମିତି ଅଛନ୍ତି?** (Kemiti achhanti?)
#
# This is the most common and polite way to say "How are you?" in Odia.
#
# If you are speaking to a close friend or someone younger than you, you might use:
# **କେମିତି ଅଛୁ?** (Kemiti achhu?) - Informal

# %% [markdown]
# ### Hugging face embedding

# %%
# !pip install -qU langchain langchain-huggingface sentence-transformers

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

# %%
embeddings= HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\Aman Deep\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Aman Deep\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
text="This is a test document"
