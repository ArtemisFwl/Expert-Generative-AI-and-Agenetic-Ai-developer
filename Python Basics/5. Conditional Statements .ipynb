# %% [markdown]
# ## Conditional Statements

# %%
x=4
r=x%2

if r==0:
    print('Even Number')
# Out:
# Even Number

# %%
x=5
r=x%2

if r==0:
    print('Even Number')
if r==1:
    print('odd number')
# Out:
# odd number

# %%
x=8
r=x%2

if r==0:
    print('Even Number')

else:
    print('Odd Number')
# Out:
# Even Number

# %%
#Check if no is even or odd
#check if hte number is greateer than smaller

# %%
x=3
r=x%2

if r==0:
    print('Even umber')
    if x>5:
        print ('Odd Number')
    else:
        print('lesser Number')

else:
    print('Odd Number')
# Out:
# Odd Number

# %%
x=5
if x==1:
    print('One')
        
elif x==2:
    print("Two")
    
elif x==3:
    print("Three")
    
else:
    print(" Number not found ")
# Out:
#  Number not found

# %% [markdown]
# -------------- Conditional statement is done-----------
