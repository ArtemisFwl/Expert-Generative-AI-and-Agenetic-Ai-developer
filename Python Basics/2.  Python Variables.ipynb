# %% [markdown]
# # Python Variables

# %%
# Everybody has a name

# %% [markdown]
# ###  Name= Variable = Identifier =object

# %% [markdown]
# #### `Syntax: Variable name= Value

# %%
a=5

# %% [markdown]
# #### value is also called datatype

# %%
id(a)
# Out:
# 140731805542320

# %%
nit=8

# %%
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-232a50ea1166> in <module>
# ----> 1 NIT
#
# NameError: name 'NIT' is not defined

# %%
4nit = 5 # variable cannot start with a number
# Out:
#   File "<ipython-input-6-2c7000863cc8>", line 1
#     4nit = 5
#      ^
# SyntaxError: invalid syntax

# %%
nit8= 10 # Varaiable can end with a number or digit

# %%
nit$ = 10 # Special character is not allowed except _ (underscore)
# Out:
#   File "<ipython-input-9-f122fd105665>", line 1
#     nit$ = 10
#        ^
# SyntaxError: invalid syntax

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
assert=10 # Cannot define keyword as a variable
# Out:
#   File "<ipython-input-18-98c8cd61ef97>", line 1
#     assert=10 # Cannot define keyword as a variable
#           ^
# SyntaxError: invalid syntax

# %%
DEF = 50 # Capiital leter is allowed . Python is case sensitive

# %%
if=7
# Out:
#   File "<ipython-input-20-512f863cc9f9>", line 1
#     if=7
#       ^
# SyntaxError: invalid syntax

# %%
If=7

# %%
### Variable Python is completed

# %% [markdown]
# ## Summary about variables
#
# #### 1.  Variables are case sensitive
# #### 2. Special Characters are not allowed. Only _ is allowed
# #### 3. Variable does not start with digit
# #### 4. Keywords are not allowed as variable name

# %% [markdown]
# ### Python value is called dataype
# - Int
# - Float
# - Bool
# - Complex
# - String

# %%
3+4
7+7
4-1
# Only latest output is printed
# Out:
# 3

# %%
#To print all the lines, we need to use print
print(3+4)
print(7+7)
print(4-1)
# Out:
# 7
# 14
# 3
