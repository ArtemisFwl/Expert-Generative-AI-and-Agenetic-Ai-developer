# %% [markdown]
# ## Topics Covered
#
# 1. PIL

# %%
from PIL import Image

# %%
horse_image= Image.open(r"C:\Users\artem\OneDrive - Indian Oil Corporation Limited\Documents\Gen AI and Agenetic AI\1. 14.12.2025 Basic Python\horse.jpg")
horse_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=487x523 at 0x2335AEB7CD0>

# %%
type(horse_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
horse_arr= np.asarray(horse_image)
horse_arr
# Out:
# array([[[ 42,  23,   8],
#         [ 43,  26,  10],
#         [ 45,  28,  12],
#         ...,
#         [200, 141,  85],
#         [187, 128,  72],
#         [178, 119,  63]],
#
#        [[ 42,  23,   8],
#         [ 43,  26,  10],
#         [ 45,  28,  12],
#         ...,
#         [201, 142,  86],
#         [190, 131,  75],
#         [182, 123,  67]],
#
#        [[ 42,  23,   8],
#         [ 43,  26,  10],
#         [ 45,  28,  12],
#         ...,
#         [203, 144,  86],
#         [193, 134,  76],
#         [185, 126,  68]],
#
#        ...,
#
#        [[ 36,  31,  27],
#         [ 36,  31,  27],
#         [ 36,  31,  27],
#         ...,
#         [ 36,  31,  27],
#         [ 36,  31,  27],
#         [ 36,  31,  27]],
#
#        [[ 36,  31,  27],
#         [ 36,  31,  27],
#         [ 36,  31,  27],
#         ...,
#         [ 36,  31,  27],
#         [ 36,  31,  27],
#         [ 36,  31,  27]],
#
#        [[ 36,  31,  27],
#         [ 36,  31,  27],
#         [ 36,  31,  27],
# ...

# %%
type(horse_arr)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(horse_image)

# %%
horse_arr.shape
# Out:
# (523, 487, 3)

# %%
plt.imshow(horse_image, cmap='BuPu')

# %%
plt.imshow(horse_arr[:,:,0], cmap='BuPu')

# %%
plt.imshow(horse_arr[:,:,0], cmap='Greys')

# %%
plt.imshow(horse_arr[:,:,0])

# %%
plt.imshow(horse_arr[:,:,1])

# %%
plt.imshow(horse_arr[:,50:150,2])
